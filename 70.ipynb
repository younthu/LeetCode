# %%
class Solution:
    def climbStairs(self, n: int) -> int:
        cs1 = 1
        cs2 = 2
        if n <= 2:
            return n
        while n > 2:
            cs1, cs2 = cs2, cs1+cs2
            n -= 1
        return cs2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 同样的代码，提交第二遍
# ![image.png](attachment:image.png)
